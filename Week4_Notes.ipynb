# %% [markdown]
# ## Week 4 Notes

# %% [markdown]
# ### Plotting with Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn']

# %%
plt.style('seaborn-colorblind')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-c1719de24463> in <module>()
# ----> 1 plt.style('seaborn-colorblind')
#
# TypeError: 'module' object is not callable

# %%
np.random.seed(123)

    ###seed with the random function holds the numbers product by the random function

df = pd.DataFrame({'a': np.random.randn(365).cumsum(0),
                   'b': np.random.randn(365).cumsum(0) + 20,
                   'c': np.random.randn(365).cumsum(0) - 20},
                   index = pd.date_range('1/1/2017', periods=365))

df.head()
# Out:
#                    a          b          c
# 2017-01-01 -1.085631  20.059291 -20.230904
# 2017-01-02 -0.088285  21.803332 -16.659325
# 2017-01-03  0.194693  20.835588 -17.055481
# 2017-01-04 -1.311601  21.255156 -17.093802
# 2017-01-05 -1.890202  21.462083 -19.518638

# %%
df.plot();
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
df.plot('a','b', kind = 'scatter');
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
df.plot.scatter('a', 'c', c='b', s=df['b'], colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
### matplotlib subplot returned

ax = df.plot.scatter('a', 'c', c='b', s=df['b'], colormap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
df.plot.box()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
df.plot.hist(alpha=0.7);
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
df.plot.kde()

    ###returns a plot the probability density function for the data
    ### come in handy when want to derive a smooth continuous function with a continuous 
    ### dataset
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

# %%
np.random.seed(1234) # sets the seed number for the random number generator which lets us reproduce this
#data in downstream calculatoins

v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(np.random.normal(60,15,1000), name='v2')
plt.hist(v1, alpha=0.7, bins=np.arange(-50, 150, 5), label='v1')
plt.hist(v2, alpha=0.7, bins=np.arange(-50,150,5), label='v2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %%
plt.figure()
plt.hist([v1, v2], histtype='barstacked', normed=True);
v3 = np.concatenate((v1, v2))
sns.kdeplot(v3);
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# C:\Users\Jason\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
plt.figure()
sns.distplot(v3, hist_kws={'color': 'Teal'}, kde_kws={'color': 'Navy'});
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# C:\Users\Jason\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
### joint plot
sns.jointplot(v1, v2, alpha=0.4);
# Out:
# <img src="data:image/png;base64,..." width="599.9999910593034">

# %%
grid = sns.jointplot(v1, v2, alpha=0.5);
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="599.9999910593034">

# %%
sns.jointplot(v1, v2, kind='hex');
# Out:
# <img src="data:image/png;base64,..." width="599.9999910593034">

# %%
sns.set_style('white')

# %%
sns.jointplot(v1, v2, kind='kde', space=0);
# Out:
# <img src="data:image/png;base64,..." width="599.9999910593034">
# C:\Users\Jason\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
ir
