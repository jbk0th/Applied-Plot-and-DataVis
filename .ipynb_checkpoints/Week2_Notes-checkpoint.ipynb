# %%
import pandas as pd
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt

os.chdir('C:\\Users\\Jason\\Applied-Plot-and-DataVis')
os.getcwd()
# Out:
# 'C:\\Users\\Jason\\Applied-Plot-and-DataVis'

# %%
# %matplotlib notebook

##turns on the interactive part of the notebook

# %%
# First let's set the backend without using mpl.use() from the scripting layer
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# create a new figure
fig = Figure()

# associate fig with the backend
canvas = FigureCanvasAgg(fig)

# add a subplot to the fig
ax = fig.add_subplot(111)

# plot the point (3,2)
ax.plot(3, 2, '.')

# save the figure to test.png
# you can see this figure in your Jupyter workspace afterwards by going to
# https://hub.coursera-notebooks.org/

# %%
linear_data = np.array([1,2,3,4,5,6,7,8])
quadratic_data = linear_data**2

plt.figure()
plt.plot(linear_data,'-o', quadratic_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
plt.plot([22,44,55], '--r')

# %%
plt.xlabel('Some Data')
plt.ylabel('Some other Data')
plt.title('A title')
plt.legend(['Baseline','Competition','Us'])

# %%
plt.figure()

observation_dates = np.arange('2017-01-01','2017-01-09', dtype='datetime64[D]')
observation_dates = list(map(pd.to_datetime, observation_dates))
plt.plot(observation_dates, linear_data, '-o',
        observation_dates, quadratic_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
x = plt.gca().xaxis

for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom=0.25)

# %%
ax = plt.gca()
ax.set_xlabel('Date')
ax.set_ylabel('Units')
ax.set_title('Quadratic vs. Linear performance')

# %% [markdown]
# ## Bar Charts

# %%
plt.figure()
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width = 0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 8 artists>

# %%
new_xvals = []
for item in xvals:
    new_xvals.append(item+0.3)
    
plt.bar(new_xvals, quadratic_data, width=0.3, color='red')
# Out:
# <Container object of 8 artists>

# %%
from random import randint
linear_err = [randint(0,15) for x in range(len(linear_data))]
plt.bar(xvals, linear_data, width=0.3, yerr=linear_err)
# Out:
# <Container object of 8 artists>

# %%
plt.figure()
xvals = range(len(linear_data))
plt.bar(xvals, linear_data, width=0.3, color='b')
plt.bar(xvals, quadratic_data, width=0.3, bottom=linear_data, color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 8 artists>

# %%
plt.figure()
xvals = range(len(linear_data))
plt.barh(xvals, linear_data, height=0.3, color='b')
plt.barh(xvals, quadratic_data, height=0.3, left=linear_data, color='r')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 8 artists>

# %% [markdown]
# ## Dejunkifying a Plot

# %%
lang_dat = {'Language':pd.Series(['Python','SQL','Java','C++','JavaScript'], index=range(5)),
            '% Popularity': pd.Series([56, 39, 34, 34, 29], index=range(5))}
df = pd.DataFrame(lang_dat)
df
# Out:
#    % Popularity    Language
# 0            56      Python
# 1            39         SQL
# 2            34        Java
# 3            34         C++
# 4            29  JavaScript

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(frameon=False)

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

## OG before changed colors plt.bar(pos, popularity, align='center')
cols=['blue','grey','grey','grey','grey']
plt.bar(pos, popularity, align='center', color=cols)


plt.xticks(pos, languages)
#plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

#TODO: remove all the ticks (both axes), and tick labels on the Y axis

plt.tick_params(axis='both',left=False, bottom=False, labelleft=False)

## impt in the documentation don't need to add the first word, I.E Axes.tick_params, only need plt.tick_params

#plt.gca().spines.set_visible(False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## Reomving the borders for the graph

#axes = plt.gca()#.spines['right'].set_visible(False) ##impt because this gets the axis that has these attributes 
#axes.spines['right'].set_visible(False)
#axes.spines['left'].set_visible(False)
#axes.spines['top'].set_visible(False)
#axes.spines['bottom'].set_visible(False)

### way more efficient way for removing the spines with a loop

# remove the frame of the chart
for spine in plt.gca().spines.values(): #  returns the value for each spine in the picture, so because you get a list back with all values can call method on each of them in figure
    spine.set_visible(False)

# %%
### Changing bar colors, and label colors
#plt.gca().xaxis.label.set_color('red')  # the reason this did not so was the axis label was off so color changed but it was not present to see  
#plt.gcf()
plt.tick_params(labelcolor='grey') ## tick labels different than axis labels
plt.gca().yaxis.label.set_color('grey') ## the axis label different than tick labels

#bars = plt.gca() # the tuple creation at the beginning of plotting with fig, ax. becuase two objects
#the above statement provides the axis object that most of the actual methods/functions are called on

rects = bars.patches
bars = plt.gca()

for patch in rects:
    height = patch.get_height()
    bars.text(patch.get_x() + patch.get_width()/2 , height - 3,'{}%'.format(str(height)), ha='center', color='white', fontsize=11)
    # get_x() gets the starting edge of the patch, get_width() returns the x 'units' the patch is across,
    # so if wanted in the center would just /2 the get_width
    #'{}'.format(argument,additionalargs**) this puts your arg in the {} area followed byb whatever else want in that space
