# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

plt.subplot?

# %%
plt.figure()
plt.subplot(1,2,1)

linear_data = np.array([1,2,3,4,5,6,7,8])

plt.plot(linear_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
exponential_data = linear_data**2

plt.subplot(1,2,2)
plt.plot(exponential_data, '-o')

# %%
plt.subplot(1, 2, 1)

plt.plot(exponential_data, '-x')

# %%
plt.figure()
ax1 = plt.subplot(1 , 2, 1)
plt.plot(linear_data, '-o')
ax2 = plt.subplot(1, 2, 2, sharey=ax1) 
plt.plot(exponential_data, '-x')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.figure()
plt.subplot(1, 2, 2) == plt.subplot(121)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# False

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, 
                                                                       sharex=True,
                                                                       sharey=True)

ax5.plot(linear_data, '-')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %%
plt.gcf().canvas.draw()

# %% [markdown]
# ### Histograms

# %%
# histogram bar chart shows the freq of a given phenom
fig, ((ax1, ax2,), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0, len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = (ax1, ax2, ax3, ax4)

for n in range(0, len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample, bins=100)
    axs[n].set_title('n={}'.format(sample_size))
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.figure()
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
plt.scatter(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
Y = np.random.normal(loc=0.0, scale= 1.0, size=10000)
X = np.random.random(size=10000)
lower_right.scatter(X, Y)
top_histogram.hist(X, bins=100)
s = side_histogram.hist(Y, bins=100, orientation='horizontal')

# %%
top_histogram.clear()
top_histogram.hist(X, bins=100, normed=True)
side_histogram.clear()
side_histogram.hist(Y, bins=100, orientation='horizontal')

side_histogram.invert_xaxis()

# %%
for ax in [top_histogram, lower_right]:
    ax.set_xlim(0, 1)
for ax in [side_histogram, lower_right]:
    ax.set_ylim(-5, 5)

# %%
# %%HTML
# <img src='http://educationxpress.mit.edu/sites/default/files/journal/WP1-Fig13.jpg' />
# Out:
# <img src='http://educationxpress.mit.edu/sites/default/files/journal/WP1-Fig13.jpg' />

# %% [markdown]
# ### Boxplots

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample,
                  'random' : random_sample,
                  'gamma' : gamma_sample})

# %%
df.describe()
# Out:
#               gamma        normal        random
# count  10000.000000  10000.000000  10000.000000
# mean       2.002940      0.006509      0.501457
# std        1.399271      0.988972      0.289462
# min        0.019851     -3.558158      0.000070
# 25%        0.967907     -0.660062      0.250777
# 50%        1.695774      0.000320      0.502051
# 75%        2.700915      0.667755      0.756558
# max       11.817890      3.862549      0.999793

# %%
### median typically the 50% of a box and whisker 
plt.figure()
_ = plt.boxplot(df['normal'], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.clf()
_ = plt.boxplot([df['normal'], df['random'], df['gamma'] ],  whis='range')

# %%
plt.figure()
_ = plt.hist(df['gamma'], bins=100)
# Out:
# <div id='12642cf8-c173-4af5-b26c-97c6f27b367c'></div>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-a260f095a3de> in <module>()
#       2 _ = plt.hist(df['gamma'], bins=100)
#       3
# ----> 4 import mpl_toolkits.axes.gridl.inset_locator as mpl_il
#
# ModuleNotFoundError: No module named 'mpl_toolkits.axes'

# %%
# import mpl_toolkits.axes.gridl.inset_locator as mpl_il, didn't ship with my package

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gammea'], ], whis='range')
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-46-94a8be12bfbc> in <module>()
# ----> 1 import mpl_toolkits.axes.gridl.inset_locator as mpl_il
#       2
#       3 plt.figure()
#       4 plt.boxplot([df['normal'], df['random'], df['gammea'], ], whis='range')
#       5 ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
#
# ModuleNotFoundError: No module named 'mpl_toolkits.axes'

# %%
 ax2.yaxis.tick_right()

# %%
plt.figure()
_ = plt.boxplot([df['normal'], df['random'], df['gamma'] ] )
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# very interesting ability to add 95% confidence interval

# %% [markdown]
# ### Heatmap

# %%
#heatmap are a way to visualize 3d data and to take advantage of the spacial proximity of those dimensions

#location data, (lat , long) then overlay 3rd var temp/rain to show its intensity
#bad if there's no continuous relationship between dimensions, categorical data is bad and spurious

plt.figure()

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
_ = plt.hist2d(X, Y, bins=25)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.figure() 
_ = plt.hist2d(X, Y, bins=100)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.colorbar()

# %% [markdown]
# ### Animation

# %%
import matplotlib.animation as animation

n=100
x = np.random.randn(n)

# %%
def update(curr):
    if curr == n:
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins=bins)
    plt.axis([-4, 4, 0, 30])
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n = {}'.format(curr), [3, 27])

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %% [markdown]
# ### Interactivity

# %%
# need to be in the artist layer and reference the canvas object of the current figure
# event listing, event driven programming
# piece of data associated with a func call
plt.figure()
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {},{} {}and data {},{}}'.format(event.x,
                                                                        event.y,
                                                                        '/n',
                                                                        event.xdata,
                                                                        event.ydata))  

pl.gcf().canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b85f948a209c> in <module>()
#      15                                                                         event.ydata))
#      16
# ---> 17 pl.gcf().canvas.mpl_connect('button_press_event', onclick)
#
# NameError: name 'pl' is not defined

# %%
# most impt event for us = pick event allows respond when someone actually click on a thing
from random import shuffle
origins = ['China', 'Brazil', 'India', 'USA', 'Canada',
          'UK', 'Germany', 'Iraq', 'Chile', 'Mexico']

shuffle(origins)

df = pd.DataFrame({'height' : np.random.rand(10),
                  'weight' : np.random.rand(10),
                  'origin' : origins})
df
# Out:
#      height   origin    weight
# 0  0.032306    India  0.707192
# 1  0.716391    Chile  0.076706
# 2  0.002061   Mexico  0.506856
# 3  0.115009   Canada  0.106789
# 4  0.523375  Germany  0.964610
# 5  0.739962    China  0.413598
# 6  0.202743      USA  0.892101
# 7  0.395029   Brazil  0.599708
# 8  0.516584       UK  0.875342
# 9  0.541620     Iraq  0.636650

# %% [markdown]
# plt.figure()
# plt.scatter(df['height'], df['weight'], picker = 5)
# plt.gca().set_ylabel('Weight')
# plt.gca().set_xlabel('Height')

# %%
def onpick(event):
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item came from {}'.format(origin))
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 7
